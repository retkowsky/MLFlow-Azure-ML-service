# %% [markdown]
# ## Use MLflow with Azure Machine Learning for Remote Training Run
#
# This example shows you how to use MLflow tracking APIs together with Azure Machine Learning services for storing your metrics and artifacts, from local Notebook run. You'll learn how to:
#
#  1. Set up MLflow tracking URI so as to use Azure ML
#  2. Create experiment
#  3. Train a model on Machine Learning Compute while logging metrics and artifacts
#  4. View your experiment within your Azure ML Workspace in Azure Portal.

# %% [markdown]
# <img src="https://github.com/retkowsky/images/blob/master/AzureMLservicebanniere.png?raw=true">

# %% [markdown]
# <img src="https://mlflow.org/docs/0.2.1/_static/MLflow-logo-final-black.png" width="400">

# %% [markdown]
# ## Prerequisites
#
# Make sure you have completed the [Configuration](../../../configuration.ipnyb) notebook to set up your Azure Machine Learning workspace and ensure other common prerequisites are met.

# %%
#pip install azureml-mlflow

# %% [markdown]
# ## Set-up
#
# Check Azure ML SDK version installed on your computer, and then connect to your Workspace.

# %%
import time
datedujour = time.strftime("%Y-%m-%d")
print(datedujour)
# Out:
# 2020-01-08

# %%
# Check core SDK version number
import azureml.core
from azureml.core import Workspace, Experiment

print("SDK version:", azureml.core.VERSION)

ws = Workspace.from_config()
# Out:
# SDK version: 1.0.72

# %% [markdown]
# Let's also create a Machine Learning Compute cluster for submitting the remote run.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

# Choose a name for your CPU cluster
cpu_cluster_name = "cpu-cluster"

# Verify that cluster does not exist already
try:
    cpu_cluster = ComputeTarget(workspace=ws, name=cpu_cluster_name)
    print("Found existing cpu-cluster")
except ComputeTargetException:
    print("Creating new cpu-cluster")
    
    # Specify the configuration for the new cluster
    compute_config = AmlCompute.provisioning_configuration(vm_size="STANDARD_D2_V2",
                                                           min_nodes=0,
                                                           max_nodes=1)

    # Create the cluster with the specified name and configuration
    cpu_cluster = ComputeTarget.create(ws, cpu_cluster_name, compute_config)
    
    # Wait for the cluster to complete, show the output log
    cpu_cluster.wait_for_completion(show_output=True)
# Out:
# Found existing cpu-cluster

# %% [markdown]
# ### Create Azure ML Experiment

# %% [markdown]
# The following steps show how to submit a training Python script to a cluster as an Azure ML run, while logging happens through MLflow APIs to your Azure ML Workspace. Let's first create an experiment to hold the training runs.

# %%
from azureml.core import Experiment

experiment_name = "MLFlow"
exp = Experiment(workspace=ws, name=experiment_name)

# %% [markdown]
# ### Instrument remote training script using MLflow

# %% [markdown]
# Let's use [*train_diabetes.py*](train_diabetes.py) to train a regression model against diabetes dataset as the example. Note that the training script uses mlflow.start_run() to start logging, and then logs metrics, saves the trained scikit-learn model, and saves a plot as an artifact.
#
# Run following command to view the script file. Notice the mlflow logging statements, and also notice that the script doesn't have explicit dependencies on azureml library.

# %%
training_script = 'train_diabetes.py'
with open(training_script, 'r') as f:
    print(f.read())
# Out:
# # Copyright (c) Microsoft. All rights reserved.
# # Licensed under the MIT license.
#
# import numpy as np
# from sklearn.datasets import load_diabetes
# from sklearn.linear_model import Ridge
# from sklearn.metrics import mean_squared_error
# from sklearn.model_selection import train_test_split
# import mlflow
# import mlflow.sklearn
#
# import matplotlib
# matplotlib.use('Agg')
# import matplotlib.pyplot as plt
#
# with mlflow.start_run():
#     X, y = load_diabetes(return_X_y=True)
#     columns = ['age', 'gender', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
#     data = {
#         "train": {"X": X_train, "y": y_train},
#         "test": {"X": X_test, "y": y_test}}
#
#     mlflow.log_metric("Training samples", len(data['train']['X']))
#     mlflow.log_metric("Test samples", len(data['test']['X']))
#
#     # Log the algorithm parameter alpha to the run
#     mlflow.log_metric('alpha', 0.03)
#     # Create, fit, and test the scikit-learn Ridge regression model
#     regression_model = Ridge(alpha=0.03)
#     regression_model.fit(data['train']['X'], data['train']['y'])
#     preds = regression_model.predict(data['test']['X'])
#
#     # Log mean squared error
#     print('Mean Squared Error is', mean_squared_error(data['test']['y'], preds))
#     mlflow.log_metric('mse', mean_squared_error(data['test']['y'], preds))
#
#     # Save the model to the outputs directory for capture
#     mlflow.sklearn.log_model(regression_model, "model")
#
#     # Plot actuals vs predictions and save the plot within the run
#     fig = plt.figure(1)
#     idx = np.argsort(data['test']['y'])
#     plt.plot(data['test']['y'][idx], preds[idx])
#     fig.savefig("actuals_vs_predictions.png")
#     mlflow.log_artifact("actuals_vs_predictions.png")

# %% [markdown]
# ### Submit Run to Cluster
#
# Let's submit the run to cluster. When running on the remote cluster as submitted run, Azure ML sets the MLflow tracking URI to point to your Azure ML Workspace, so that the metrics and artifacts are automatically logged there.
#
# Note that you have to specify the packages your script depends on, including *azureml-mlflow* that implicitly enables the MLflow logging to Azure ML.
#
# First, create a environment with Docker enable and required package dependencies specified.

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies

env = Environment(name="mlflow-env")

env.docker.enabled = True

# Specify conda dependencies with scikit-learn and temporary pointers to mlflow extensions
cd = CondaDependencies.create(
    conda_packages=["scikit-learn", "matplotlib"],
    pip_packages=["azureml-mlflow", "numpy"]
    )

env.python.conda_dependencies = cd

# %% [markdown]
# Next, specify a script run configuration that includes the training script, environment and CPU cluster created earlier.

# %%
from azureml.core import ScriptRunConfig

src = ScriptRunConfig(source_directory=".", script=training_script)
src.run_config.environment = env
src.run_config.target = cpu_cluster.name

# %% [markdown]
# Finally, submit the run. Note that the first instance of the run typically takes longer as the Docker-based environment is created, several minutes. Subsequent runs reuse the image and are faster.

# %%
# %%time
run = exp.submit(src)
run.wait_for_completion(show_output=True)
# Out:
# RunId: MLFlow_1578489177_74b589f6
# Web View: https://ml.azure.com/experiments/MLFlow/runs/MLFlow_1578489177_74b589f6?wsid=/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourcegroups/azuremlserviceresourcegroup/workspaces/azuremlservice
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
# 2020/01/08 13:13:08 Downloading source code...
# 2020/01/08 13:13:10 Finished downloading source code
# 2020/01/08 13:13:11 Creating Docker network: acb_default_network, driver: 'bridge'
# 2020/01/08 13:13:11 Successfully set up Docker network: acb_default_network
# 2020/01/08 13:13:11 Setting up Docker configuration...
# 2020/01/08 13:13:12 Successfully set up Docker configuration
# 2020/01/08 13:13:12 Logging in to registry: azuremlservice8791701193.azurecr.io
# 2020/01/08 13:13:13 Successfully logged into azuremlservice8791701193.azurecr.io
# 2020/01/08 13:13:13 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/01/08 13:13:13 Scanning for dependencies...
# 2020/01/08 13:13:14 Successfully scanned dependencies
# 2020/01/08 13:13:14 Launching container with name: acb_step_0
# Sending build context to Docker daemon  59.39kB
#
#
# Step 1/15 : FROM mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04@sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
# sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05: Pulling from azureml/base
# Digest: sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
# Status: Downloaded newer image for mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04@sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
#  ---> 93a72e6bd1ce
# Step 2/15 : USER root
#  ---> Running in 3f6185b90018
# Removing intermediate container 3f6185b90018
#  ---> e5faea95b800
# Step 3/15 : RUN mkdir -p $HOME/.cache
#  ---> Running in 21a52c4a9c04
# Removing intermediate container 21a52c4a9c04
#  ---> 5f23b9cf3039
# Step 4/15 : WORKDIR /
#  ---> Running in 7e879d98f64a
# Removing intermediate container 7e879d98f64a
#  ---> 9a6a66667ee1
# Step 5/15 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 4e19d5489286
# Step 6/15 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 49d7abd646c6
# Removing intermediate container 49d7abd646c6
#  ---> 83487bb90159
# Step 7/15 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 527f6ca307a9
# Step 8/15 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_253e51566379597e6e89e411b061cf72 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in ae40b9c4e5bb
# Solving environment: ...working...
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.8.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# sqlite-3.20.1        | 1.3 MB    |            |   0%
# sqlite-3.20.1        | 1.3 MB    | #######9   |  80%
# sqlite-3.20.1        | 1.3 MB    | #########8 |  99%
# sqlite-3.20.1        | 1.3 MB    | ########## | 100%
#
# libxml2-2.9.10       | 1.3 MB    |            |   0%
# libxml2-2.9.10       | 1.3 MB    | #######8   |  79%
# libxml2-2.9.10       | 1.3 MB    | #########8 |  98%
# libxml2-2.9.10       | 1.3 MB    | ########## | 100%
#
# icu-64.2             | 12.6 MB   |            |   0%
# icu-64.2             | 12.6 MB   | ##7        |  27%
# icu-64.2             | 12.6 MB   | #######5   |  75%
# icu-64.2             | 12.6 MB   | #########  |  90%
# icu-64.2             | 12.6 MB   | ########## | 100%
#
# xorg-renderproto-0.1 | 8 KB      |            |   0%
# xorg-renderproto-0.1 | 8 KB      | ########## | 100%
#
# libgomp-9.2.0        | 795 KB    |            |   0%
# libgomp-9.2.0        | 795 KB    | ########6  |  87%
# libgomp-9.2.0        | 795 KB    | ########## | 100%
#
# wheel-0.33.6         | 35 KB     |            |   0%
# wheel-0.33.6         | 35 KB     | ########## | 100%
#
# xorg-libice-1.0.10   | 57 KB     |            |   0%
# xorg-libice-1.0.10   | 57 KB     | ########## | 100%
#
# xorg-libxext-1.3.4   | 51 KB     |            |   0%
# xorg-libxext-1.3.4   | 51 KB     | ########## | 100%
#
# libgcc-ng-9.2.0      | 8.2 MB    |            |   0%
# libgcc-ng-9.2.0      | 8.2 MB    | ###1       |  32%
# libgcc-ng-9.2.0      | 8.2 MB    | #######5   |  76%
# libgcc-ng-9.2.0      | 8.2 MB    | #########3 |  93%
# libgcc-ng-9.2.0      | 8.2 MB    | ########## | 100%
#
# setuptools-44.0.0    | 640 KB    |            |   0%
# setuptools-44.0.0    | 640 KB    | ########2  |  83%
# setuptools-44.0.0    | 640 KB    | ########## | 100%
#
# scipy-1.4.1          | 18.9 MB   |            |   0%
# scipy-1.4.1          | 18.9 MB   | ##         |  21%
# scipy-1.4.1          | 18.9 MB   | ####3      |  43%
# scipy-1.4.1          | 18.9 MB   | #######5   |  75%
# scipy-1.4.1          | 18.9 MB   | #########  |  90%
# scipy-1.4.1          | 18.9 MB   | ########## | 100%
#
# xorg-libx11-1.6.9    | 918 KB    |            |   0%
# xorg-libx11-1.6.9    | 918 KB    | ########3  |  84%
# xorg-libx11-1.6.9    | 918 KB    | ########## | 100%
#
# cycler-0.10.0        | 9 KB      |            |   0%
# cycler-0.10.0        | 9 KB      | ########## | 100%
#
# pango-1.42.4         | 517 KB    |            |   0%
# pango-1.42.4         | 517 KB    | ########3  |  83%
# pango-1.42.4         | 517 KB    | ########## | 100%
#
# libstdcxx-ng-9.2.0   | 4.5 MB    |            |   0%
# libstdcxx-ng-9.2.0   | 4.5 MB    | #######5   |  75%
# libstdcxx-ng-9.2.0   | 4.5 MB    | #########7 |  98%
# libstdcxx-ng-9.2.0   | 4.5 MB    | ########## | 100%
#
# pthread-stubs-0.4    | 5 KB      |            |   0%
# pthread-stubs-0.4    | 5 KB      | ########## | 100%
#
# libpng-1.6.37        | 343 KB    |            |   0%
# libpng-1.6.37        | 343 KB    | #########5 |  95%
# libpng-1.6.37        | 343 KB    | ########## | 100%
#
# xorg-libxrender-0.9. | 31 KB     |            |   0%
# xorg-libxrender-0.9. | 31 KB     | ########## | 100%
#
# six-1.13.0           | 22 KB     |            |   0%
# six-1.13.0           | 22 KB     | ########## | 100%
#
# joblib-0.14.1        | 198 KB    |            |   0%
# joblib-0.14.1        | 198 KB    | ########## | 100%
#
# python-dateutil-2.8. | 220 KB    |            |   0%
# python-dateutil-2.8. | 220 KB    | ########## | 100%
#
# tornado-6.0.3        | 636 KB    |            |   0%
# tornado-6.0.3        | 636 KB    | ########2  |  83%
# tornado-6.0.3        | 636 KB    | ########## | 100%
#
# scikit-learn-0.22.1  | 7.1 MB    |            |   0%
# scikit-learn-0.22.1  | 7.1 MB    | #####8     |  59%
# scikit-learn-0.22.1  | 7.1 MB    | #######6   |  76%
# scikit-learn-0.22.1  | 7.1 MB    | #########1 |  92%
# scikit-learn-0.22.1  | 7.1 MB    | ########## | 100%
#
# libiconv-1.15        | 2.0 MB    |            |   0%
# libiconv-1.15        | 2.0 MB    | ########   |  81%
# libiconv-1.15        | 2.0 MB    | #########8 |  99%
# libiconv-1.15        | 2.0 MB    | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# xorg-xproto-7.0.31   | 72 KB     |            |   0%
# xorg-xproto-7.0.31   | 72 KB     | ########## | 100%
#
# qt-4.8.7             | 32.7 MB   |            |   0%
# qt-4.8.7             | 32.7 MB   | #5         |  16%
# qt-4.8.7             | 32.7 MB   | ###4       |  34%
# qt-4.8.7             | 32.7 MB   | #####5     |  55%
# qt-4.8.7             | 32.7 MB   | #######5   |  75%
# qt-4.8.7             | 32.7 MB   | ########9  |  90%
# qt-4.8.7             | 32.7 MB   | ########## | 100%
#
# glib-2.58.3          | 3.3 MB    |            |   0%
# glib-2.58.3          | 3.3 MB    | #######5   |  75%
# glib-2.58.3          | 3.3 MB    | #########7 |  98%
# glib-2.58.3          | 3.3 MB    | ########## | 100%
#
# pcre-8.43            | 257 KB    |            |   0%
# pcre-8.43            | 257 KB    | #########9 | 100%
# pcre-8.43            | 257 KB    | ########## | 100%
#
# libxcb-1.13          | 396 KB    |            |   0%
# libxcb-1.13          | 396 KB    | ########2  |  83%
# libxcb-1.13          | 396 KB    | ########## | 100%
#
# ca-certificates-2019 | 145 KB    |            |   0%
# ca-certificates-2019 | 145 KB    | ########## | 100%
#
# pip-19.3.1           | 1.9 MB    |            |   0%
# pip-19.3.1           | 1.9 MB    | #######7   |  77%
# pip-19.3.1           | 1.9 MB    | #########1 |  92%
# pip-19.3.1           | 1.9 MB    | ########## | 100%
#
# libffi-3.2.1         | 46 KB     |            |   0%
# libffi-3.2.1         | 46 KB     | ########## | 100%
#
# readline-7.0         | 1.1 MB    |            |   0%
# readline-7.0         | 1.1 MB    | ########1  |  81%
# readline-7.0         | 1.1 MB    | ########## | 100%
#
# pyqt-4.11.4          | 3.5 MB    |            |   0%
# pyqt-4.11.4          | 3.5 MB    | #######5   |  76%
# pyqt-4.11.4          | 3.5 MB    | #########8 |  98%
# pyqt-4.11.4          | 3.5 MB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | #8         |  18%
# python-3.6.2         | 27.0 MB   | ####2      |  42%
# python-3.6.2         | 27.0 MB   | ######9    |  69%
# python-3.6.2         | 27.0 MB   | ########5  |  85%
# python-3.6.2         | 27.0 MB   | #########6 |  96%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# matplotlib-3.1.2     | 7 KB      |            |   0%
# matplotlib-3.1.2     | 7 KB      | ########## | 100%
#
# libopenblas-0.3.7    | 7.6 MB    |            |   0%
# libopenblas-0.3.7    | 7.6 MB    | ######4    |  64%
# libopenblas-0.3.7    | 7.6 MB    | ########3  |  84%
# libopenblas-0.3.7    | 7.6 MB    | #########8 |  98%
# libopenblas-0.3.7    | 7.6 MB    | ########## | 100%
#
# zlib-1.2.11          | 105 KB    |            |   0%
# zlib-1.2.11          | 105 KB    | ########## | 100%
#
# freetype-2.10.0      | 884 KB    |            |   0%
# freetype-2.10.0      | 884 KB    | ########5  |  86%
# freetype-2.10.0      | 884 KB    | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | #######6   |  77%
# tk-8.6.10            | 3.2 MB    | #########2 |  93%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# certifi-2019.11.28   | 149 KB    |            |   0%
# certifi-2019.11.28   | 149 KB    | ########## | 100%
#
# harfbuzz-2.4.0       | 1.5 MB    |            |   0%
# harfbuzz-2.4.0       | 1.5 MB    | ########   |  81%
# harfbuzz-2.4.0       | 1.5 MB    | ########## | 100%
#
# xorg-libxau-1.0.9    | 13 KB     |            |   0%
# xorg-libxau-1.0.9    | 13 KB     | ########## | 100%
#
# kiwisolver-1.1.0     | 86 KB     |            |   0%
# kiwisolver-1.1.0     | 86 KB     | ########## | 100%
#
# xorg-xextproto-7.3.0 | 27 KB     |            |   0%
# xorg-xextproto-7.3.0 | 27 KB     | ########## | 100%
#
# gettext-0.19.8.1     | 3.6 MB    |            |   0%
# gettext-0.19.8.1     | 3.6 MB    | #######6   |  76%
# gettext-0.19.8.1     | 3.6 MB    | #########4 |  95%
# gettext-0.19.8.1     | 3.6 MB    | ########## | 100%
#
# cairo-1.16.0         | 1.5 MB    |            |   0%
# cairo-1.16.0         | 1.5 MB    | ########   |  81%
# cairo-1.16.0         | 1.5 MB    | ########## | 100%
#
# liblapack-3.8.0      | 10 KB     |            |   0%
# liblapack-3.8.0      | 10 KB     | ########## | 100%
#
# sip-4.18             | 263 KB    |            |   0%
# sip-4.18             | 263 KB    | ########## | 100%
#
# libcblas-3.8.0       | 10 KB     |            |   0%
# libcblas-3.8.0       | 10 KB     | ########## | 100%
#
# pixman-0.38.0        | 594 KB    |            |   0%
# pixman-0.38.0        | 594 KB    | #########  |  91%
# pixman-0.38.0        | 594 KB    | ########## | 100%
#
# xorg-libxdmcp-1.1.3  | 18 KB     |            |   0%
# xorg-libxdmcp-1.1.3  | 18 KB     | ########## | 100%
#
# numpy-1.17.3         | 5.2 MB    |            |   0%
# numpy-1.17.3         | 5.2 MB    | #######5   |  75%
# numpy-1.17.3         | 5.2 MB    | #########7 |  98%
# numpy-1.17.3         | 5.2 MB    | ########## | 100%
#
# fribidi-1.0.5        | 112 KB    |            |   0%
# fribidi-1.0.5        | 112 KB    | ########## | 100%
#
# xorg-kbproto-1.0.7   | 26 KB     |            |   0%
# xorg-kbproto-1.0.7   | 26 KB     | ########## | 100%
#
# libblas-3.8.0        | 10 KB     |            |   0%
# libblas-3.8.0        | 10 KB     | ########## | 100%
#
# xz-5.2.4             | 366 KB    |            |   0%
# xz-5.2.4             | 366 KB    | #########4 |  95%
# xz-5.2.4             | 366 KB    | ########## | 100%
#
# matplotlib-base-3.1. | 6.7 MB    |            |   0%
# matplotlib-base-3.1. | 6.7 MB    | ####1      |  42%
# matplotlib-base-3.1. | 6.7 MB    | #######5   |  76%
# matplotlib-base-3.1. | 6.7 MB    | #########1 |  92%
# matplotlib-base-3.1. | 6.7 MB    | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.7 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.7 MB    | #######8   |  78%
# libgfortran-ng-7.3.0 | 1.7 MB    | #########9 |  99%
# libgfortran-ng-7.3.0 | 1.7 MB    | ########## | 100%
#
# libuuid-2.32.1       | 26 KB     |            |   0%
# libuuid-2.32.1       | 26 KB     | ########## | 100%
#
# pyparsing-2.4.6      | 59 KB     |            |   0%
# pyparsing-2.4.6      | 59 KB     | ########## | 100%
#
# openssl-1.0.2u       | 3.2 MB    |            |   0%
# openssl-1.0.2u       | 3.2 MB    | #######6   |  76%
# openssl-1.0.2u       | 3.2 MB    | #########3 |  94%
# openssl-1.0.2u       | 3.2 MB    | ########## | 100%
#
# fontconfig-2.13.1    | 340 KB    |            |   0%
# fontconfig-2.13.1    | 340 KB    | #########7 |  98%
# fontconfig-2.13.1    | 340 KB    | ########## | 100%
#
# xorg-libsm-1.2.3     | 25 KB     |            |   0%
# xorg-libsm-1.2.3     | 25 KB     | ########## | 100%
#
# ncurses-6.0          | 920 KB    |            |   0%
# ncurses-6.0          | 920 KB    | #######9   |  79%
# ncurses-6.0          | 920 KB    | #########1 |  91%
# ncurses-6.0          | 920 KB    | ########## | 100%
#
# openmp_impl-4.5      | 435 KB    |            |   0%
# openmp_impl-4.5      | 435 KB    | ########## | 100%
#
# graphite2-1.3.13     | 109 KB    |            |   0%
# graphite2-1.3.13     | 109 KB    | ########## | 100%
# Downloading and Extracting Packages
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting azureml-mlflow==1.0.72.*
#   Downloading https://files.pythonhosted.org/packages/ef/83/6b1832280ee9677ca2a278d8216d6337657f12497579f1740537ec90262e/azureml_mlflow-1.0.72.1-py2.py3-none-any.whl
# Requirement already satisfied: numpy in /azureml-envs/azureml_253e51566379597e6e89e411b061cf72/lib/python3.6/site-packages (from -r /azureml-environment-setup/condaenv.gmfrzfik.requirements.txt (line 2)) (1.17.3)
# Collecting jsonpickle
#   Downloading https://files.pythonhosted.org/packages/07/07/c157520a3ebd166c8c24c6ae0ecae7c3968eb4653ff0e5af369bb82f004d/jsonpickle-1.2-py2.py3-none-any.whl
# Collecting mlflow<1.4,>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/95/eb/91b42c744e75e4523b29ca8d746a43fddb9def239adae5d5071e4044c760/mlflow-1.3.0.tar.gz (14.4MB)
# Collecting azureml-core==1.0.72.*
#   Downloading https://files.pythonhosted.org/packages/b3/40/5f3478937e925a44a92c343b97f71243e9bcbedebc50f67038df044c97d9/azureml_core-1.0.72-py2.py3-none-any.whl (1.1MB)
# Collecting alembic
#   Downloading https://files.pythonhosted.org/packages/dc/6d/3c1411dfdcf089ec89ce5e2222deb2292f39b6b1a5911222e15af9fe5a92/alembic-1.3.2.tar.gz (1.1MB)
# Collecting click>=7.0
#   Downloading https://files.pythonhosted.org/packages/fa/37/45185cb5abbc30d7257104c434fe0b07e5a195a6847506c074527aa599ec/Click-7.0-py2.py3-none-any.whl (81kB)
# Collecting cloudpickle
#   Downloading https://files.pythonhosted.org/packages/c1/49/334e279caa3231255725c8e860fa93e72083567625573421db8875846c14/cloudpickle-1.2.2-py2.py3-none-any.whl
# Collecting databricks-cli>=0.8.7
#   Downloading https://files.pythonhosted.org/packages/85/03/fb0c4d31559d48f15403ad88aefff8ae0dddbbeab273d198c20232a937c2/databricks-cli-0.9.1.tar.gz (45kB)
# Collecting requests>=2.17.3
#   Downloading https://files.pythonhosted.org/packages/51/bd/23c926cd341ea6b7dd0b2a00aba99ae0f828be89d72b2190f27c11d4b7fb/requests-2.22.0-py2.py3-none-any.whl (57kB)
# Requirement already satisfied: six>=1.10.0 in /azureml-envs/azureml_253e51566379597e6e89e411b061cf72/lib/python3.6/site-packages (from mlflow<1.4,>=1.0.0->azureml-mlflow==1.0.72.*->-r /azureml-environment-setup/condaenv.gmfrzfik.requirements.txt (line 1)) (1.13.0)
# Collecting Flask
#   Downloading https://files.pythonhosted.org/packages/9b/93/628509b8d5dc749656a9641f4caf13540e2cdec85276964ff8f43bbb1d3b/Flask-1.1.1-py2.py3-none-any.whl (94kB)
# Collecting pandas
#   Downloading https://files.pythonhosted.org/packages/52/3f/f6a428599e0d4497e1595030965b5ba455fd8ade6e977e3c819973c4b41d/pandas-0.25.3-cp36-cp36m-manylinux1_x86_64.whl (10.4MB)
# Requirement already satisfied: python-dateutil in /azureml-envs/azureml_253e51566379597e6e89e411b061cf72/lib/python3.6/site-packages (from mlflow<1.4,>=1.0.0->azureml-mlflow==1.0.72.*->-r /azureml-environment-setup/condaenv.gmfrzfik.requirements.txt (line 1)) (2.8.1)
# Collecting protobuf>=3.6.0
#   Downloading https://files.pythonhosted.org/packages/ca/ac/838c8c8a5f33a58132dd2ad2a30329f6ae1614a9f56ffb79eaaf71a9d156/protobuf-3.11.2-cp36-cp36m-manylinux1_x86_64.whl (1.3MB)
# Collecting gitpython>=2.1.0
#   Downloading https://files.pythonhosted.org/packages/20/8c/4543981439d23c4ff65b2e62dddd767ebc84a8e664a9b67e840d1e2730d3/GitPython-3.0.5-py3-none-any.whl (455kB)
# Collecting pyyaml
#   Downloading https://files.pythonhosted.org/packages/3d/d9/ea9816aea31beeadccd03f1f8b625ecf8f645bd66744484d162d84803ce5/PyYAML-5.3.tar.gz (268kB)
# Collecting querystring_parser
#   Downloading https://files.pythonhosted.org/packages/4a/fa/f54f5662e0eababf0c49e92fd94bf178888562c0e7b677c8941bbbcd1bd6/querystring_parser-1.2.4.tar.gz
# Collecting simplejson
#   Downloading https://files.pythonhosted.org/packages/98/87/a7b98aa9256c8843f92878966dc3d8d914c14aad97e2c5ce4798d5743e07/simplejson-3.17.0.tar.gz (83kB)
# Collecting docker>=4.0.0
#   Downloading https://files.pythonhosted.org/packages/cc/ca/699d4754a932787ef353a157ada74efd1ceb6d1fc0bfb7989ae1e7b33111/docker-4.1.0-py2.py3-none-any.whl (139kB)
# Collecting entrypoints
#   Downloading https://files.pythonhosted.org/packages/ac/c6/44694103f8c221443ee6b0041f69e2740d89a25641e62fb4f2ee568f2f9c/entrypoints-0.3-py2.py3-none-any.whl
# Collecting sqlparse
#   Downloading https://files.pythonhosted.org/packages/ef/53/900f7d2a54557c6a37886585a91336520e5539e3ae2423ff1102daf4f3a7/sqlparse-0.3.0-py2.py3-none-any.whl
# Collecting sqlalchemy
#   Downloading https://files.pythonhosted.org/packages/17/7f/35879c73859368ad19a952b69ee780aa97fc30350dabd45fb948d6a4e3ea/SQLAlchemy-1.3.12.tar.gz (6.0MB)
# Collecting gorilla
#   Downloading https://files.pythonhosted.org/packages/e3/56/5a683944cbfc77e429c6f03c636ca50504a785f60ffae91ddd7f5f7bb520/gorilla-0.3.0-py2.py3-none-any.whl
# Collecting gunicorn
#   Downloading https://files.pythonhosted.org/packages/69/ca/926f7cd3a2014b16870086b2d0fdc84a9e49473c68a8dff8b57f7c156f43/gunicorn-20.0.4-py2.py3-none-any.whl (77kB)
# Collecting contextlib2
#   Downloading https://files.pythonhosted.org/packages/85/60/370352f7ef6aa96c52fb001831622f50f923c1d575427d021b8ab3311236/contextlib2-0.6.0.post1-py2.py3-none-any.whl
# Collecting azure-mgmt-storage>=1.5.0
#   Downloading https://files.pythonhosted.org/packages/5b/ee/1415439cbbbffce8c9cc9a55b4c0313a2f2a995f9655acfa5aa7344e6d8f/azure_mgmt_storage-7.0.0-py2.py3-none-any.whl (516kB)
# Collecting adal>=1.2.0
#   Downloading https://files.pythonhosted.org/packages/4f/b5/3ea9ae3d1096b9ff31e8f1846c47d49f3129a12464ac0a73b602de458298/adal-1.2.2-py2.py3-none-any.whl (53kB)
# Collecting PyJWT
#   Downloading https://files.pythonhosted.org/packages/87/8b/6a9f14b5f781697e51259d81657e6048fd31a113229cf346880bb7545565/PyJWT-1.7.1-py2.py3-none-any.whl
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading https://files.pythonhosted.org/packages/ca/9a/7cece52c46546e214e10811b36b2da52ce1ea7fa203203a629b8dfadad53/cryptography-2.8-cp34-abi3-manylinux2010_x86_64.whl (2.3MB)
# Collecting azure-mgmt-resource>=1.2.1
#   Downloading https://files.pythonhosted.org/packages/10/2a/26db9b79f00699e6033f0667dd950085daeb6abf84ae765adfa092f59e37/azure_mgmt_resource-7.0.0-py2.py3-none-any.whl (757kB)
# Collecting jmespath
#   Downloading https://files.pythonhosted.org/packages/83/94/7179c3832a6d45b266ddb2aac329e101367fbdb11f425f13771d27f225bb/jmespath-0.9.4-py2.py3-none-any.whl
# Collecting pathspec
#   Downloading https://files.pythonhosted.org/packages/34/fa/c5cc4f796eb954b56fd1f6c7c315647b18b027e0736c9ae87b73bbb1f933/pathspec-0.7.0-py2.py3-none-any.whl
# Collecting azure-common>=1.1.12
#   Downloading https://files.pythonhosted.org/packages/3f/4b/8881f8446853dfe3d404468689edcff33c0e2bf62ac2ddf31d08d739fadc/azure_common-1.1.24-py2.py3-none-any.whl
# Collecting ruamel.yaml<=0.15.89,>=0.15.35
#   Downloading https://files.pythonhosted.org/packages/36/e1/cc2fa400fa5ffde3efa834ceb15c464075586de05ca3c553753dcd6f1d3b/ruamel.yaml-0.15.89-cp36-cp36m-manylinux1_x86_64.whl (651kB)
# Collecting msrest>=0.5.1
#   Downloading https://files.pythonhosted.org/packages/27/b0/c34b3ea9b2ed74b800520fbefb312cdb7f05c20b8bd42e5e7662a5614f98/msrest-0.6.10-py2.py3-none-any.whl (82kB)
# Collecting azure-mgmt-keyvault>=0.40.0
#   Downloading https://files.pythonhosted.org/packages/b3/d1/9fed0a3a3b43d0b1ad59599b5c836ccc4cf117e26458075385bafe79575b/azure_mgmt_keyvault-2.0.0-py2.py3-none-any.whl (80kB)
# Collecting pyopenssl
#   Downloading https://files.pythonhosted.org/packages/9e/de/f8342b68fa9e981d348039954657bdf681b2ab93de27443be51865ffa310/pyOpenSSL-19.1.0-py2.py3-none-any.whl (53kB)
# Collecting backports.tempfile
#   Downloading https://files.pythonhosted.org/packages/b4/5c/077f910632476281428fe254807952eb47ca78e720d059a46178c541e669/backports.tempfile-1.0-py2.py3-none-any.whl
# Collecting urllib3>=1.23
#   Downloading https://files.pythonhosted.org/packages/b4/40/a9837291310ee1ccc242ceb6ebfd9eb21539649f193a7c8c86ba15b98539/urllib3-1.25.7-py2.py3-none-any.whl (125kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/97/70/8c2d0509db466678eba16fa2b0a539499f3b351b1f2993126ad843d5be13/azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718kB)
# Collecting msrestazure>=0.4.33
#   Downloading https://files.pythonhosted.org/packages/68/75/5cb56ca8cbc6c5fe476e4878c73f57a331edcf55e5d3fcb4a7377d7d659d/msrestazure-0.6.2-py2.py3-none-any.whl (40kB)
# Collecting azure-graphrbac>=0.40.0
#   Downloading https://files.pythonhosted.org/packages/3e/93/02056aca45162f9fc275d1eaad12a2a07ef92375afb48eabddc4134b8315/azure_graphrbac-0.61.1-py2.py3-none-any.whl (141kB)
# Collecting SecretStorage
#   Downloading https://files.pythonhosted.org/packages/82/59/cb226752e20d83598d7fdcabd7819570b0329a61db07cfbdd21b2ef546e3/SecretStorage-3.1.1-py3-none-any.whl
# Collecting ndg-httpsclient
#   Downloading https://files.pythonhosted.org/packages/fb/67/c2f508c00ed2a6911541494504b7cac16fe0b0473912568df65fd1801132/ndg_httpsclient-0.5.1-py3-none-any.whl
# Collecting pytz
#   Downloading https://files.pythonhosted.org/packages/e7/f9/f0b53f88060247251bf481fa6ea62cd0d25bf1b11a87888e53ce5b7c8ad2/pytz-2019.3-py2.py3-none-any.whl (509kB)
# Collecting azure-mgmt-authorization>=0.40.0
#   Downloading https://files.pythonhosted.org/packages/5e/17/4724694ddb3311955ddc367eddcd0928f8ee2c7b12d5a6f0b12bca0b03db/azure_mgmt_authorization-0.60.0-py2.py3-none-any.whl (82kB)
# Collecting Mako
#   Downloading https://files.pythonhosted.org/packages/b0/3c/8dcd6883d009f7cae0f3157fb53e9afb05a0d3d33b3db1268ec2e6f4a56b/Mako-1.1.0.tar.gz (463kB)
# Collecting python-editor>=0.3
#   Downloading https://files.pythonhosted.org/packages/c6/d3/201fc3abe391bbae6606e6f1d598c15d367033332bd54352b12f35513717/python_editor-1.0.4-py3-none-any.whl
# Collecting tabulate>=0.7.7
#   Downloading https://files.pythonhosted.org/packages/c4/41/523f6a05e6dc3329a5660f6a81254c6cd87e5cfb5b7482bae3391d86ec3a/tabulate-0.8.6.tar.gz (45kB)
# Collecting configparser>=0.3.5
#   Downloading https://files.pythonhosted.org/packages/7a/2a/95ed0501cf5d8709490b1d3a3f9b5cf340da6c433f896bbe9ce08dbe6785/configparser-4.0.2-py2.py3-none-any.whl
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_253e51566379597e6e89e411b061cf72/lib/python3.6/site-packages (from requests>=2.17.3->mlflow<1.4,>=1.0.0->azureml-mlflow==1.0.72.*->-r /azureml-environment-setup/condaenv.gmfrzfik.requirements.txt (line 1)) (2019.11.28)
# Collecting chardet<3.1.0,>=3.0.2
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
# Collecting idna<2.9,>=2.5
#   Downloading https://files.pythonhosted.org/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl (58kB)
# Collecting Werkzeug>=0.15
#   Downloading https://files.pythonhosted.org/packages/ce/42/3aeda98f96e85fd26180534d36570e4d18108d62ae36f87694b476b83d6f/Werkzeug-0.16.0-py2.py3-none-any.whl (327kB)
# Collecting itsdangerous>=0.24
#   Downloading https://files.pythonhosted.org/packages/76/ae/44b03b253d6fade317f32c24d100b3b35c2239807046a4c953c7b89fa49e/itsdangerous-1.1.0-py2.py3-none-any.whl
# Collecting Jinja2>=2.10.1
#   Downloading https://files.pythonhosted.org/packages/65/e0/eb35e762802015cab1ccee04e8a277b03f1d8e53da3ec3106882ec42558b/Jinja2-2.10.3-py2.py3-none-any.whl (125kB)
# Requirement already satisfied: setuptools in /azureml-envs/azureml_253e51566379597e6e89e411b061cf72/lib/python3.6/site-packages (from protobuf>=3.6.0->mlflow<1.4,>=1.0.0->azureml-mlflow==1.0.72.*->-r /azureml-environment-setup/condaenv.gmfrzfik.requirements.txt (line 1)) (44.0.0.post20200102)
# Collecting gitdb2>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/03/6c/99296f89bad2ef85626e1df9f677acbee8885bb043ad82ad3ed4746d2325/gitdb2-2.0.6-py2.py3-none-any.whl (63kB)
# Collecting websocket-client>=0.32.0
#   Downloading https://files.pythonhosted.org/packages/4c/5f/f61b420143ed1c8dc69f9eaec5ff1ac36109d52c80de49d66e0c36c3dfdf/websocket_client-0.57.0-py2.py3-none-any.whl (200kB)
# Collecting cffi!=1.11.3,>=1.8
#   Downloading https://files.pythonhosted.org/packages/49/72/0d42f94fe94afa8030350c26e9d787219f3f008ec9bf6b86c66532b29236/cffi-1.13.2-cp36-cp36m-manylinux1_x86_64.whl (397kB)
# Collecting isodate>=0.6.0
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading https://files.pythonhosted.org/packages/a3/12/b92740d845ab62ea4edf04d2f4164d82532b5a0b03836d4d4e71c6f3d379/requests_oauthlib-1.3.0-py2.py3-none-any.whl
# Collecting backports.weakref
#   Downloading https://files.pythonhosted.org/packages/88/ec/f598b633c3d5ffe267aaada57d961c94fdfa183c5c3ebda2b6d151943db6/backports.weakref-1.0.post1-py2.py3-none-any.whl
# Collecting jeepney
#   Downloading https://files.pythonhosted.org/packages/ae/35/7e580cfed452e3b8c3cca44290adc54b8b5a5b8e37f89da5d24b09318be8/jeepney-0.4.2-py3-none-any.whl
# Collecting pyasn1>=0.1.1
#   Downloading https://files.pythonhosted.org/packages/62/1e/a94a8d635fa3ce4cfc7f506003548d0a2447ae76fd5ca53932970fe3053f/pyasn1-0.4.8-py2.py3-none-any.whl (77kB)
# Collecting MarkupSafe>=0.9.2
#   Downloading https://files.pythonhosted.org/packages/b2/5f/23e0023be6bb885d00ffbefad2942bc51a620328ee910f64abe5a8d18dd1/MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting smmap2>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/55/d2/866d45e3a121ee15a1dc013824d58072fd5c7799c9c34d01378eb262ca8f/smmap2-2.0.5-py2.py3-none-any.whl
# Collecting pycparser
#   Downloading https://files.pythonhosted.org/packages/68/9e/49196946aee219aead1290e00d1e7fdeab8567783e83e1b9ab5585e6206a/pycparser-2.19.tar.gz (158kB)
# Collecting oauthlib>=3.0.0
#   Downloading https://files.pythonhosted.org/packages/05/57/ce2e7a8fa7c0afb54a0581b14a65b56e62b5759dbc98e80627142b8a3704/oauthlib-3.1.0-py2.py3-none-any.whl (147kB)
# Building wheels for collected packages: mlflow, alembic, databricks-cli, pyyaml, querystring-parser, simplejson, sqlalchemy, Mako, tabulate, pycparser
#   Building wheel for mlflow (setup.py): started
#   Building wheel for mlflow (setup.py): finished with status 'done'
#   Created wheel for mlflow: filename=mlflow-1.3.0-cp36-none-any.whl size=14540341 sha256=5736509f4c8ed89c942ea426e1bdc79a61d6b1cbee396739077319a654bdc8f2
#   Stored in directory: /root/.cache/pip/wheels/f1/e0/1c/663c9b2bb00f32c235c98a43c39d81c2a25544a889a32649ea
#   Building wheel for alembic (setup.py): started
#   Building wheel for alembic (setup.py): finished with status 'done'
#   Created wheel for alembic: filename=alembic-1.3.2-py2.py3-none-any.whl size=151128 sha256=332c102e444599a2bad83c322f8fd8ce6519e8da07d833daad9f6f623bd71272
#   Stored in directory: /root/.cache/pip/wheels/5c/66/53/e0633382ac8625ab1c099db6a290d1b6b24f849a4666a57105
#   Building wheel for databricks-cli (setup.py): started
#   Building wheel for databricks-cli (setup.py): finished with status 'done'
#   Created wheel for databricks-cli: filename=databricks_cli-0.9.1-cp36-none-any.whl size=83754 sha256=f6b0f2e7fa6282c2f094e41b443f1fb750370a703403bc401d2e7d9e4ce296b2
#   Stored in directory: /root/.cache/pip/wheels/bc/27/58/c6ef96e649962e9584a50f58d5b6abafb71a03512b2e381ad1
#   Building wheel for pyyaml (setup.py): started
#   Building wheel for pyyaml (setup.py): finished with status 'done'
#   Created wheel for pyyaml: filename=PyYAML-5.3-cp36-cp36m-linux_x86_64.whl size=44229 sha256=c6e61de9260ce971b194de0cf9b9191e8a6925d45018ea65a3b90001389a552f
#   Stored in directory: /root/.cache/pip/wheels/e4/76/4d/a95b8dd7b452b69e8ed4f68b69e1b55e12c9c9624dd962b191
#   Building wheel for querystring-parser (setup.py): started
#   Building wheel for querystring-parser (setup.py): finished with status 'done'
#   Created wheel for querystring-parser: filename=querystring_parser-1.2.4-cp36-none-any.whl size=7078 sha256=e6eb5629e304238d7dc6c1447afae3daab5719993b41da4e5e7c8dec59929d0c
#   Stored in directory: /root/.cache/pip/wheels/1e/41/34/23ebf5d1089a9aed847951e0ee375426eb4ad0a7079d88d41e
#   Building wheel for simplejson (setup.py): started
#   Building wheel for simplejson (setup.py): finished with status 'done'
#   Created wheel for simplejson: filename=simplejson-3.17.0-cp36-cp36m-linux_x86_64.whl size=117669 sha256=9ae10ad2fef34107c22c692f71d0539633426cf69bee9677150c54615391332f
#   Stored in directory: /root/.cache/pip/wheels/86/c0/83/dcd0339abb2640544bb8e0938aab2d069cef55e5647ce6e097
#   Building wheel for sqlalchemy (setup.py): started
#   Building wheel for sqlalchemy (setup.py): finished with status 'done'
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.3.12-cp36-cp36m-linux_x86_64.whl size=1201372 sha256=7df8b8d630e261d327bf09c21365f5bc6817cf33498ea7027a933cc29cadaf09
#   Stored in directory: /root/.cache/pip/wheels/ee/33/44/0788a6e806866ae2e246d5cd841d07498a46bcb3f3c42ea5a4
#   Building wheel for Mako (setup.py): started
#   Building wheel for Mako (setup.py): finished with status 'done'
#   Created wheel for Mako: filename=Mako-1.1.0-cp36-none-any.whl size=75363 sha256=a0217d7ebf92c7643953cc909038f1f6937ebfac78068813bebdb4f533def379
#   Stored in directory: /root/.cache/pip/wheels/98/32/7b/a291926643fc1d1e02593e0d9e247c5a866a366b8343b7aa27
#   Building wheel for tabulate (setup.py): started
#   Building wheel for tabulate (setup.py): finished with status 'done'
#   Created wheel for tabulate: filename=tabulate-0.8.6-cp36-none-any.whl size=23271 sha256=a00cbe5a2e3b805cd25a3210b51408c34daf1094a9e211ada800f9e4422c8499
#   Stored in directory: /root/.cache/pip/wheels/9c/9b/f4/eb243fdb89676ec00588e8c54bb54360724c06e7fafe95278e
#   Building wheel for pycparser (setup.py): started
#   Building wheel for pycparser (setup.py): finished with status 'done'
#   Created wheel for pycparser: filename=pycparser-2.19-py2.py3-none-any.whl size=111029 sha256=9150d7c96e65b598ecd9142695d6958b6ac61ea1a9303188d639b8f999e7344a
#   Stored in directory: /root/.cache/pip/wheels/f2/9a/90/de94f8556265ddc9d9c8b271b0f63e57b26fb1d67a45564511
# Successfully built mlflow alembic databricks-cli pyyaml querystring-parser simplejson sqlalchemy Mako tabulate pycparser
# Installing collected packages: jsonpickle, sqlalchemy, MarkupSafe, Mako, python-editor, alembic, click, cloudpickle, urllib3, chardet, idna, requests, tabulate, configparser, databricks-cli, Werkzeug, itsdangerous, Jinja2, Flask, pytz, pandas, protobuf, smmap2, gitdb2, gitpython, pyyaml, querystring-parser, simplejson, websocket-client, docker, entrypoints, sqlparse, gorilla, gunicorn, mlflow, contextlib2, isodate, oauthlib, requests-oauthlib, msrest, PyJWT, pycparser, cffi, cryptography, adal, msrestazure, azure-common, azure-mgmt-storage, azure-mgmt-resource, jmespath, pathspec, ruamel.yaml, azure-mgmt-keyvault, pyopenssl, backports.weakref, backports.tempfile, azure-mgmt-containerregistry, azure-graphrbac, jeepney, SecretStorage, pyasn1, ndg-httpsclient, azure-mgmt-authorization, azureml-core, azureml-mlflow
# Successfully installed Flask-1.1.1 Jinja2-2.10.3 Mako-1.1.0 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.1.1 Werkzeug-0.16.0 adal-1.2.2 alembic-1.3.2 azure-common-1.1.24 azure-graphrbac-0.61.1 azure-mgmt-authorization-0.60.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.0.0 azure-mgmt-resource-7.0.0 azure-mgmt-storage-7.0.0 azureml-core-1.0.72 azureml-mlflow-1.0.72.1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.13.2 chardet-3.0.4 click-7.0 cloudpickle-1.2.2 configparser-4.0.2 contextlib2-0.6.0.post1 cryptography-2.8 databricks-cli-0.9.1 docker-4.1.0 entrypoints-0.3 gitdb2-2.0.6 gitpython-3.0.5 gorilla-0.3.0 gunicorn-20.0.4 idna-2.8 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.4.2 jmespath-0.9.4 jsonpickle-1.2 mlflow-1.3.0 msrest-0.6.10 msrestazure-0.6.2 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pandas-0.25.3 pathspec-0.7.0 protobuf-3.11.2 pyasn1-0.4.8 pycparser-2.19 pyopenssl-19.1.0 python-editor-1.0.4 pytz-2019.3 pyyaml-5.3 querystring-parser-1.2.4 requests-2.22.0 requests-oauthlib-1.3.0 ruamel.yaml-0.15.89 simplejson-3.17.0 smmap2-2.0.5 sqlalchemy-1.3.12 sqlparse-0.3.0 tabulate-0.8.6 urllib3-1.25.7 websocket-client-0.57.0
#
# #
# # To activate this environment, use:
# # > source activate /azureml-envs/azureml_253e51566379597e6e89e411b061cf72
# #
# # To deactivate an active environment, use:
# # > source deactivate
# #
#
#
# Removing intermediate container ae40b9c4e5bb
#  ---> 28e2246a4ec1
# Step 9/15 : ENV PATH /azureml-envs/azureml_253e51566379597e6e89e411b061cf72/bin:$PATH
#  ---> Running in 4a732700a2ee
# Removing intermediate container 4a732700a2ee
#  ---> 700316b4cb27
# Step 10/15 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_253e51566379597e6e89e411b061cf72
#  ---> Running in a2bd58e5c69d
# Removing intermediate container a2bd58e5c69d
#  ---> 86ba2d74c54c
# Step 11/15 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_253e51566379597e6e89e411b061cf72/lib:$LD_LIBRARY_PATH
#  ---> Running in 3133ff991752
# Removing intermediate container 3133ff991752
#  ---> f51b4c510dd3
# Step 12/15 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> dda368929841
# Step 13/15 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 9806e2ff16aa
# Removing intermediate container 9806e2ff16aa
#  ---> d13284482797
# Step 14/15 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 04bc1d80a8a0
# Removing intermediate container 04bc1d80a8a0
#  ---> 9f1bc2a7ef25
# Step 15/15 : CMD ["bash"]
#  ---> Running in fc5b73607109
# Removing intermediate container fc5b73607109
#  ---> de304d3318b5
# Successfully built de304d3318b5
# Successfully tagged azuremlservice8791701193.azurecr.io/azureml/azureml_a1c64b7c7a7449ee70ec47de9d3700d4:latest
# 2020/01/08 13:16:56 Successfully executed container: acb_step_0
# 2020/01/08 13:16:56 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/01/08 13:16:56 Pushing image: azuremlservice8791701193.azurecr.io/azureml/azureml_a1c64b7c7a7449ee70ec47de9d3700d4:latest, attempt 1
# The push refers to repository [azuremlservice8791701193.azurecr.io/azureml/azureml_a1c64b7c7a7449ee70ec47de9d3700d4]
# 7383f5164c3c: Preparing
# 431249f5589f: Preparing
# 65a654e35134: Preparing
# c31b3f43bc6f: Preparing
# fbd894c43a23: Preparing
# 74dcb6f47a4e: Preparing
# e1171d4d60ca: Preparing
# 6ef1a8ae63b7: Preparing
# 85389f9ead9e: Preparing
# f2608f66a0e3: Preparing
# 0e259b09e5f4: Preparing
# 340dc32eb998: Preparing
# df18b66efaa6: Preparing
# ccdb13a20bf2: Preparing
# 9513cdf4e497: Preparing
# 7f083f9454c0: Preparing
# 29f36b5893dc: Preparing
# f2608f66a0e3: Waiting
# 0e259b09e5f4: Waiting
# 340dc32eb998: Waiting
# df18b66efaa6: Waiting
# ccdb13a20bf2: Waiting
# 9513cdf4e497: Waiting
# 7f083f9454c0: Waiting
# 29f36b5893dc: Waiting
# 74dcb6f47a4e: Waiting
# e1171d4d60ca: Waiting
# 6ef1a8ae63b7: Waiting
# 85389f9ead9e: Waiting
# 65a654e35134: Pushed
# fbd894c43a23: Pushed
# 7383f5164c3c: Pushed
# c31b3f43bc6f: Pushed
# e1171d4d60ca: Pushed
# 74dcb6f47a4e: Pushed
# 6ef1a8ae63b7: Pushed
#
# 340dc32eb998: Pushed
# 0e259b09e5f4: Pushed
# ccdb13a20bf2: Pushed
# 9513cdf4e497: Pushed
# 7f083f9454c0: Pushed
# 85389f9ead9e: Pushed
# f2608f66a0e3: Pushed
# 431249f5589f: Pushed
# df18b66efaa6: Pushed
# 29f36b5893dc: Pushed
# latest: digest: sha256:2c378e8826ea9e49e1127f19cff3898694d5fe2208054d4279c488442da55ed8 size: 3883
# 2020/01/08 13:19:01 Successfully pushed image: azuremlservice8791701193.azurecr.io/azureml/azureml_a1c64b7c7a7449ee70ec47de9d3700d4:latest
# 2020/01/08 13:19:01 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 222.645222)
# 2020/01/08 13:19:01 Populating digests for step ID: acb_step_0...
# 2020/01/08 13:19:03 Successfully populated digests for step ID: acb_step_0
# 2020/01/08 13:19:03 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 124.937230)
# 2020/01/08 13:19:03 The following dependencies were found:
# 2020/01/08 13:19:03
# - image:
#     registry: azuremlservice8791701193.azurecr.io
#     repository: azureml/azureml_a1c64b7c7a7449ee70ec47de9d3700d4
#     tag: latest
#     digest: sha256:2c378e8826ea9e49e1127f19cff3898694d5fe2208054d4279c488442da55ed8
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/base
#     tag: intelmpi2018.3-ubuntu16.04
#     digest: sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
#   git: {}
#
# Run ID: cbaj was successful after 5m56s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_816501a330b966920579488689ef61504db30cd5e4e36ac0688ef88b7ec785fb_d.txt
# ========================================================================================================================
#
# 2020-01-08T13:23:42Z Starting output-watcher...
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_a1c64b7c7a7449ee70ec47de9d3700d4
# a1298f4ce990: Pulling fs layer
# 04a3282d9c4b: Pulling fs layer
# 9b0d3db6dc03: Pulling fs layer
# 8269c605f3f1: Pulling fs layer
# 6504d449e70c: Pulling fs layer
# 4e38f320d0d4: Pulling fs layer
# b0a763e8ee03: Pulling fs layer
# 11917a028ca4: Pulling fs layer
# a6c378d11cbf: Pulling fs layer
# 6cc007ad9140: Pulling fs layer
# 6c1698a608f3: Pulling fs layer
# 4935b195e75f: Pulling fs layer
# dca11c5a8faa: Pulling fs layer
# e210e5f02e59: Pulling fs layer
# cdad04d18a0a: Pulling fs layer
# 78085b947999: Pulling fs layer
# 9e8a13d0b5e4: Pulling fs layer
# a6c378d11cbf: Waiting
# 6cc007ad9140: Waiting
# 6c1698a608f3: Waiting
# 4935b195e75f: Waiting
# dca11c5a8faa: Waiting
# e210e5f02e59: Waiting
# cdad04d18a0a: Waiting
# 78085b947999: Waiting
# 9e8a13d0b5e4: Waiting
# 4e38f320d0d4: Waiting
# b0a763e8ee03: Waiting
# 8269c605f3f1: Waiting
# 6504d449e70c: Waiting
# 11917a028ca4: Waiting
# a1298f4ce990: Verifying Checksum
# a1298f4ce990: Download complete
# 04a3282d9c4b: Verifying Checksum
# 04a3282d9c4b: Download complete
# 9b0d3db6dc03: Verifying Checksum
# 9b0d3db6dc03: Download complete
# a1298f4ce990: Pull complete
# 04a3282d9c4b: Pull complete
# 9b0d3db6dc03: Pull complete
# 8269c605f3f1: Verifying Checksum
# 8269c605f3f1: Download complete
# 8269c605f3f1: Pull complete
# 4e38f320d0d4: Verifying Checksum
# 4e38f320d0d4: Download complete
# 6504d449e70c: Verifying Checksum
# 6504d449e70c: Download complete
# b0a763e8ee03: Verifying Checksum
# b0a763e8ee03: Download complete
# 11917a028ca4: Verifying Checksum
# 11917a028ca4: Download complete
# a6c378d11cbf: Verifying Checksum
# a6c378d11cbf: Download complete
# 6504d449e70c: Pull complete
# 6cc007ad9140: Verifying Checksum
# 6cc007ad9140: Download complete
# 4935b195e75f: Verifying Checksum
# 4935b195e75f: Download complete
# 6c1698a608f3: Download complete
# dca11c5a8faa: Verifying Checksum
# dca11c5a8faa: Download complete
# e210e5f02e59: Download complete
# cdad04d18a0a: Verifying Checksum
# cdad04d18a0a: Download complete
# 4e38f320d0d4: Pull complete
# 9e8a13d0b5e4: Verifying Checksum
# 9e8a13d0b5e4: Download complete
# 78085b947999: Verifying Checksum
# 78085b947999: Download complete
# b0a763e8ee03: Pull complete
# 11917a028ca4: Pull complete
# a6c378d11cbf: Pull complete
# 6cc007ad9140: Pull complete
# 6c1698a608f3: Pull complete
# 4935b195e75f: Pull complete
# dca11c5a8faa: Pull complete
# e210e5f02e59: Pull complete
# cdad04d18a0a: Pull complete
# 78085b947999: Pull complete
# 9e8a13d0b5e4: Pull complete
# Digest: sha256:2c378e8826ea9e49e1127f19cff3898694d5fe2208054d4279c488442da55ed8
# Status: Downloaded newer image for azuremlservice8791701193.azurecr.io/azureml/azureml_a1c64b7c7a7449ee70ec47de9d3700d4:latest
# b80208df1e7fde91d52b4caedcdcbc5b5ef42522c8c8857da94be4f83fa68b76
# 2020/01/08 13:25:20 Version: 3.0.01069.0001 Branch: master Commit: 00200ea2
# 2020/01/08 13:25:21 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/01/08 13:25:21 sshd runtime has already been installed in the container
# ssh-keygen: /azureml-envs/azureml_253e51566379597e6e89e411b061cf72/lib/libcrypto.so.1.0.0: no version information available (required by ssh-keygen)
# ssh-keygen: /azureml-envs/azureml_253e51566379597e6e89e411b061cf72/lib/libcrypto.so.1.0.0: no version information available (required by ssh-keygen)
#
# Streaming azureml-logs/65_job_prep-tvmps_816501a330b966920579488689ef61504db30cd5e4e36ac0688ef88b7ec785fb_d.txt
# ===============================================================================================================
#
# Starting job preparation. Current time:2020-01-08T13:25:30.472234
# Extracting the control code.
# Creating directory: azureml-logs/
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
#
# Starting the daemon thread to refresh tokens in background for process with pid = 145
# Entering Run History Context Manager.
# Mean Squared Error is 3424.900315896017
#
# Execution Summary
# =================
# RunId: MLFlow_1578489177_74b589f6
# Web View: https://ml.azure.com/experiments/MLFlow/runs/MLFlow_1578489177_74b589f6?wsid=/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourcegroups/azuremlserviceresourcegroup/workspaces/azuremlservice
# {'runId': 'MLFlow_1578489177_74b589f6',
#  'target': 'cpu-cluster',
#  'status': 'Completed',
#  'startTimeUtc': '2020-01-08T13:23:28.571728Z',
#  'endTimeUtc': '2020-01-08T13:25:47.920Z',
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': '942d5480-9481-4715-86f3-1f5f1e70dd10',
#   'AzureML.DerivedImageName': 'azureml/azureml_a1c64b7c7a7449ee70ec47de9d3700d4',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [],
#  'runDefinition': {'script': 'train_diabetes.py',
#   'arguments': [],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'cpu-cluster',
#   'dataReferences': {},
#   'data': {},
#   'jobName': None,
#   'maxRunDurationSeconds': None,
#   'nodeCount': 1,
#   'environment': {'name': 'mlflow-env',
#    'version': 'Autosave_2020-01-08T13:12:59Z_9a63d81c',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'channels': ['conda-forge'],
#      'dependencies': ['python=3.6.2',
#       {'pip': ['azureml-mlflow==1.0.72.*', 'numpy']},
#       'scikit-learn',
#       'matplotlib'],
#      'name': 'azureml_253e51566379597e6e89e411b061cf72'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04',
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': True,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': True,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []}},
#  'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://azuremlservice8628362969.blob.core.windows.net/azureml/ExperimentRun/dcid.MLFlow_1578489177_74b589f6/azureml-logs/20_image_build_log.txt?sv=2019-02-02&sr=b&sig=MlXeJoR%2FzawRztzVRM9CGpshpxhIu%2BQibGry6cYA2uo%3D&st=2020-01-08T13%3A15%3A48Z&se=2020-01-08T21%3A25%3A48Z&sp=r',
#   'azureml-logs/55_azureml-execution-tvmps_816501a330b966920579488689ef61504db30cd5e4e36ac0688ef88b7ec785fb_d.txt': 'https://azuremlservice8628362969.blob.core.windows.net/azureml/ExperimentRun/dcid.MLFlow_1578489177_74b589f6/azureml-logs/55_azureml-execution-tvmps_816501a330b966920579488689ef61504db30cd5e4e36ac0688ef88b7ec785fb_d.txt?sv=2019-02-02&sr=b&sig=bWHaNGQje%2Fx9rl31srPhp7Ie7LGy5lvcZfiCwhwuXJw%3D&st=2020-01-08T13%3A15%3A48Z&se=2020-01-08T21%3A25%3A48Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_816501a330b966920579488689ef61504db30cd5e4e36ac0688ef88b7ec785fb_d.txt': 'https://azuremlservice8628362969.blob.core.windows.net/azureml/ExperimentRun/dcid.MLFlow_1578489177_74b589f6/azureml-logs/65_job_prep-tvmps_816501a330b966920579488689ef61504db30cd5e4e36ac0688ef88b7ec785fb_d.txt?sv=2019-02-02&sr=b&sig=%2BOpKloOxCeOxWUH8udRqQbWfFILdQYyp3BZlVnAsUKM%3D&st=2020-01-08T13%3A15%3A48Z&se=2020-01-08T21%3A25%3A48Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://azuremlservice8628362969.blob.core.windows.net/azureml/ExperimentRun/dcid.MLFlow_1578489177_74b589f6/azureml-logs/70_driver_log.txt?sv=2019-02-02&sr=b&sig=dc19HaaXKqFXCS6wpE71dhcQGzOzjQjndAf0QyK%2BkGM%3D&st=2020-01-08T13%3A15%3A48Z&se=2020-01-08T21%3A25%3A48Z&sp=r',
#   'azureml-logs/process_info.json': 'https://azuremlservice8628362969.blob.core.windows.net/azureml/ExperimentRun/dcid.MLFlow_1578489177_74b589f6/azureml-logs/process_info.json?sv=2019-02-02&sr=b&sig=PDc%2FuSppBVdXe18OaLGmktV%2BHnc9YLNSIrAPjh6w3rg%3D&st=2020-01-08T13%3A15%3A48Z&se=2020-01-08T21%3A25%3A48Z&sp=r',
#   'azureml-logs/process_status.json': 'https://azuremlservice8628362969.blob.core.windows.net/azureml/ExperimentRun/dcid.MLFlow_1578489177_74b589f6/azureml-logs/process_status.json?sv=2019-02-02&sr=b&sig=J3EsFSVHqkhQHrD5lW%2BPChdWH02kFyXWQLAcwnL3nTs%3D&st=2020-01-08T13%3A15%3A48Z&se=2020-01-08T21%3A25%3A48Z&sp=r'}}

# %% [markdown]
# You can navigate to your Azure ML Workspace at Azure Portal to view the run metrics and artifacts.

# %%
run
# Out:
# Run(Experiment: MLFlow,
# Id: MLFlow_1578489177_74b589f6,
# Type: azureml.scriptrun,
# Status: Completed)

# %% [markdown]
# You can also get the metrics and bring them to your local notebook, and view the details of the run.

# %%
run.get_metrics()
# Out:
# {'Training samples': 353.0,
#  'Test samples': 89.0,
#  'alpha': 0.03,
#  'mse': 3424.900315896017}

# %%
ws.get_details()
# Out:
# {'id': '/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourceGroups/azuremlserviceresourcegroup/providers/Microsoft.MachineLearningServices/workspaces/azuremlservice',
#  'name': 'azuremlservice',
#  'location': 'westeurope',
#  'type': 'Microsoft.MachineLearningServices/workspaces',
#  'tags': {'market': 'Serge', 'Cost Center': 'Internal Azure Cost Center'},
#  'sku': 'Enterprise',
#  'workspaceid': 'b7a492c5-1d27-4c35-99bf-ef22bdee0fbb',
#  'description': '',
#  'friendlyName': '',
#  'creationTime': '2019-03-27T16:29:47.5576428+00:00',
#  'containerRegistry': '/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourcegroups/azuremlserviceresourcegroup/providers/microsoft.containerregistry/registries/azuremlservice8791701193',
#  'keyVault': '/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourcegroups/azuremlserviceresourcegroup/providers/microsoft.keyvault/vaults/azuremlservice7711339503',
#  'applicationInsights': '/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourcegroups/azuremlserviceresourcegroup/providers/microsoft.insights/components/azuremlservice6148518173',
#  'identityPrincipalId': '26c48b54-b205-44fd-8948-fecfb4131ba9',
#  'identityTenantId': '72f988bf-86f1-41af-91ab-2d7cd011db47',
#  'identityType': 'SystemAssigned',
#  'storageAccount': '/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourcegroups/azuremlserviceresourcegroup/providers/microsoft.storage/storageaccounts/azuremlservice8628362969'}
